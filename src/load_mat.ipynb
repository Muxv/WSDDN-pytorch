# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from scipy.io import loadmat

# %%
def copy(src_info, dst_layer, idx):
    """
    dst_layer : nn.Conv2d
    """
    layer = src_info[idx]
    kernel, bias = layer[0]['weights'][0][0]
    # in mat data  weight is w, h, c, bs
    dst_layer.weight.data.copy_(torch.from_numpy(kernel.transpose(3, 2, 1, 0)))
    dst_layer.bias.data.copy_(torch.from_numpy(bias.reshape(-1)))

# %%
class VGG_CNN_F(nn.Module):
    def __init__(self):
        super(VGG_CNN_F, self).__init__()
        self.conv1 = nn.Conv2d(3, 
                               64, 
                               kernel_size=11,
                               stride=4,
                               padding=0)
        self.lrn1 = nn.LocalResponseNorm(size=5,
                                         alpha=1e-4,
                                         beta=0.75,
                                         k=2)
        self.pool1 = nn.MaxPool2d(kernel_size=3,
                                  stride=2)

        self.conv2 = nn.Conv2d(64,
                               256,
                               kernel_size=5,
                               stride=1,
                               padding=2)
        self.lrn2 = nn.LocalResponseNorm(size=5,
                                         alpha=1e-4,
                                         beta=0.75,
                                         k=2)
        self.pool2 = nn.MaxPool2d(kernel_size=3,
                                  stride=2)
        self.conv3 = nn.Conv2d(256,
                               256,
                               kernel_size=3,
                               stride=1,
                               padding=1)
        self.conv4 = nn.Conv2d(256,
                               256,
                               kernel_size=3,
                               stride=1,
                               padding=1)
        self.conv5 = nn.Conv2d(256,
                               256,
                               kernel_size=3,
                               stride=1,
                               padding=1)


    def forward(self, x):
        out = self.conv1(x)
        out = self.pool1(self.lrn1(F.relu(out)))
        
        out = self.conv2(out)
        out = self.pool2(self.lrn2(F.relu(out)))

        out = F.relu(self.conv3(out))
        out = F.relu(self.conv4(out))
        out = F.relu(self.conv5(out))
        return out

    def load_mat(self, mat_path="../pretrained/imagenet-vgg-f.mat"):
        """
        idx    layer
        0       conv1
        4       conv2
        8       conv3
        10      conv4
        12      conv5
        """
        conv_idx = [0, 4, 8, 10, 12]
        conv_list = [self.conv1, self.conv2, self.conv3, self.conv4, self.conv5]
        cnn_f_weights = loadmat(mat_path)
        layers_info = cnn_f_weights['layers'][0];
        for i in range(len(conv_idx)):
            copy(layers_info, conv_list[i], conv_idx[i])

# %%
class VGG_CNN_M_1024(nn.Module):
    def __init__(self):
        super(VGG_CNN_M_1024, self).__init__()
        self.conv1 = nn.Conv2d(3, 
                               96, 
                               kernel_size=7,
                               stride=2,
                               padding=0)
        self.lrn1 = nn.LocalResponseNorm(size=5,
                                         alpha=1e-4,
                                         beta=0.75,
                                         k=2)
        self.pool1 = nn.MaxPool2d(kernel_size=3,
                                  stride=2)

        self.conv2 = nn.Conv2d(96,
                               256,
                               kernel_size=5,
                               stride=2,
                               padding=1)
        self.lrn2 = nn.LocalResponseNorm(size=5,
                                         alpha=1e-4,
                                         beta=0.75,
                                         k=2)
        self.pool2 = nn.MaxPool2d(kernel_size=3,
                                  stride=2)
        self.conv3 = nn.Conv2d(256,
                               512,
                               kernel_size=3,
                               stride=1,
                               padding=1)
        self.conv4 = nn.Conv2d(512,
                               512,
                               kernel_size=3,
                               stride=1,
                               padding=1)
        self.conv5 = nn.Conv2d(512,
                               512,
                               kernel_size=3,
                               stride=1,
                               padding=1)


    def forward(self, x):
        out = self.conv1(x)
        out = self.pool1(self.lrn1(F.relu(out)))
        
        out = self.conv2(out)
        out = self.pool2(self.lrn2(F.relu(out)))

        out = F.relu(self.conv3(out))
        out = F.relu(self.conv4(out))
        out = F.relu(self.conv5(out))
        return out

    def load_mat(self, mat_path="../pretrained/imagenet-vgg-m-1024.mat"):
        """
        idx    layer
        0       conv1
        4       conv2
        8       conv3
        10      conv4
        12      conv5
        """
        conv_idx = [0, 4, 8, 10, 12]
        conv_list = [self.conv1, self.conv2, self.conv3, self.conv4, self.conv5]
        cnn_f_weights = loadmat(mat_path)
        layers_info = cnn_f_weights['layers'][0];
        for i in range(len(conv_idx)):
            copy(layers_info, conv_list[i], conv_idx[i])

# %%
class VGG_VD_1024(nn.Module):
    def __init__(self):
        super(VGG_VD_1024, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1)
        self.conv2 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, stride=1)
        self.conv4 = nn.Conv2d(128, 128, kernel_size=3, stride=1)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        
        self.conv5 = nn.Conv2d(128, 256, kernel_size=3, stride=1)
        self.conv6 = nn.Conv2d(256, 256, kernel_size=3, stride=1)
        self.conv7 = nn.Conv2d(256, 256, kernel_size=3, stride=1)
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)
        
        self.conv8 = nn.Conv2d(256, 512, kernel_size=3, stride=1)
        self.conv9 = nn.Conv2d(512, 512, kernel_size=3, stride=1)
        self.conv10 = nn.Conv2d(512, 512, kernel_size=3, stride=1)
        self.pool4 = nn.MaxPool2d(kernel_size=2, stride=2)
        
        self.conv11 = nn.Conv2d(512, 512, kernel_size=3, stride=1)
        self.conv12 = nn.Conv2d(512, 512, kernel_size=3, stride=1)
        self.conv13 = nn.Conv2d(512, 512, kernel_size=3, stride=1)
        
        

    def forward(self, x):
        out = F.relu(self.conv1(x))
        out = self.pool1(F.relu(self.conv2(out)))
        
        out = F.relu(self.conv3(out))
        out = self.pool2(F.relu(self.conv4(out)))
        
        out = F.relu(self.conv5(out))
        out = F.relu(self.conv6(out))
        out = self.pool3(F.relu(self.conv7(out)))
        
        out = F.relu(self.conv8(out))
        out = F.relu(self.conv9(out))
        out = self.pool4(F.relu(self.conv10(out)))
        
        out = F.relu(self.conv11(out))
        out = F.relu(self.conv12(out))
        out = F.relu(self.conv13(out))
        
        return out

    def load_mat(self, mat_path="../pretrained/imagenet-matconvnet-vgg-verydeep-16.mat"):
        conv_idx = [0, 2, 5, 7, 10, 12, 14, 17, 19, 21, 24, 26, 28]
        conv_list = [self.conv1, self.conv2, self.conv3, self.conv4, 
                     self.conv5, self.conv6, self.conv7, self.conv8,
                     self.conv9, self.conv10, self.conv11, self.conv12,
                     self.conv13]
        cnn_f_weights = loadmat(mat_path)
        layers_info = cnn_f_weights['layers'][0];
        for i in range(len(conv_idx)):
            copy(layers_info, conv_list[i], conv_idx[i])

# %%
#cnn_f_weights = loadmat("../region/SelectiveSearchVOC2007trainval.mat")
# layers_info = cnn_f_weights['layers'][0];
wsddn = loadmat("../pretrained/wsddn.mat")

# %%
def print_all(o):
    for x in o:
        print(x)

# %%
fc6c = wsddn['params'][0][10][1]
fc6b = wsddn['params'][0][11][1]

# %%
wsddn['params'][0][8][1].shape
# Out:
# (3, 3, 256, 256)

# %%
fc6b.shape
# Out:
# (4096, 1)

# %%
fc6c.shape
# Out:
# (6, 6, 256, 4096)

# %%
voc_07_wws['params'][0][10][1].shape
# Out:
# (6, 6, 256, 4096)

# %%
print_all(wsddn['layers'][0][18])
# Out:
# ['fc8C']
# ['dagnn.Conv']
# [[array(['x19'], dtype='<U3')]]
# [[array(['xfc8C'], dtype='<U5')]]
# [[array(['fc8Cf'], dtype='<U5') array(['fc8Cb'], dtype='<U5')]]
# [[(array([[   1,    1, 4096,   20]], dtype=uint16), array([[1]], dtype=uint8), array([], shape=(0, 0), dtype=object), array([[0, 0, 0, 0]], dtype=uint8), array([[1, 1]], dtype=uint8), array([[1, 1]], dtype=uint8))]]

# %%
wsddn
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Wed Mar 28 11:18:10 2018',
#  '__version__': '1.0',
#  '__globals__': [],
#  'vars': array([[(array(['input'], dtype='<U5'), array([[0]], dtype=uint8)),
#          (array(['x1'], dtype='<U2'), array([[0]], dtype=uint8)),
#          (array(['x2'], dtype='<U2'), array([[0]], dtype=uint8)),
#          (array(['x3'], dtype='<U2'), array([[0]], dtype=uint8)),
#          (array(['x4'], dtype='<U2'), array([[0]], dtype=uint8)),
#          (array(['x5'], dtype='<U2'), array([[0]], dtype=uint8)),
#          (array(['x6'], dtype='<U2'), array([[0]], dtype=uint8)),
#          (array(['x7'], dtype='<U2'), array([[0]], dtype=uint8)),
#          (array(['x8'], dtype='<U2'), array([[0]], dtype=uint8)),
#          (array(['x9'], dtype='<U2'), array([[0]], dtype=uint8)),
#          (array(['x10'], dtype='<U3'), array([[0]], dtype=uint8)),
#          (array(['x11'], dtype='<U3'), array([[0]], dtype=uint8)),
#          (array(['x12'], dtype='<U3'), array([[0]], dtype=uint8)),
#          (array(['x13'], dtype='<U3'), array([[0]], dtype=uint8)),
#          (array(['x14'], dtype='<U3'), array([[0]], dtype=uint8)),
#          (array(['xBoostBox'], dtype='<U9'), array([[0]], dtype=uint8)),
#          (array(['x15'], dtype='<U3'), array([[0]], dtype=uint8)),
#          (array(['x16'], dtype='<U3'), array([[0]], dtype=uint8)),
#          (array(['x18'], dtype='<U3'), array([[0]], dtype=uint8)),
#          (array(['x19'], dtype='<U3'), array([[0]], dtype=uint8)),
#          (array(['xfc8C'], dtype='<U5'), array([[0]], dtype=uint8)),
#          (array(['x22'], dtype='<U3'), array([[0]], dtype=uint8)),
#          (array(['rois'], dtype='<U4'), array([[0]], dtype=uint8)),
#          (array(['xSPP'], dtype='<U4'), array([[0]], dtype=uint8)),
#          (array(['boxScore'], dtype='<U8'), array([[0]], dtype=uint8)),
#          (array(['xSoftmaxDet'], dtype='<U11'), array([[0]], dtype=uint8)),
#          (array(['xSoftmaxCls'], dtype='<U11'), array([[0]], dtype=uint8)),
#          (array(['xTimes'], dtype='<U6'), array([[0]], dtype=uint8)),
#          (array(['prediction'], dtype='<U10'), array([[0]], dtype=uint8))]],
#        dtype=[('name', 'O'), ('precious', 'O')]),
#  'params': array([[(array(['conv1f'], dtype='<U6'), array([[[[-8.17205291e-03,  7.65486807e-03,  3.28400284e-02, ...,
#            -1.93343107e-02, -6.20526029e-03,  5.05123101e-03],
#           [ 1.65013820e-02, -3.75030353e-03,  7.46346777e-04, ...,
#            -3.34549397e-02,  2.49612983e-03,  6.09367294e-03],
#           [ 5.81715442e-03, -1.87785570e-02, -4.72146384e-02, ...,
#            -3.31286192e-02,  5.16303303e-03,  1.98464678e-03]],
#
#          [[-1.71663519e-02,  1.68408845e-02,  3.74678262e-02, ...,
#            -1.36153605e-02, -4.50473018e-02, -2.52077077e-02],
#           [ 2.24809013e-02,  9.57741775e-03,  7.27735227e-03, ...,
#            -2.03316305e-02, -2.76107211e-02, -1.18659064e-02],
#           [ 5.87535463e-03, -1.12472950e-02, -3.94462086e-02, ...,
#            -2.89309695e-02, -3.96387391e-02, -3.28576602e-02]],
#
#          [[-1.30177457e-02,  1.43637424e-02,  3.12952287e-02, ...,
#             2.49776244e-02,  6.51134625e-02,  1.84125733e-02],
#           [ 2.49945186e-02, -6.81696227e-03,  2.58125039e-03, ...,
#             9.01446864e-03,  6.97417855e-02,  1.90115422e-02],
#           [ 2.90906224e-02, -1.00546069e-02, -4.08449583e-02, ...,
#             1.12199569e-02,  7.00299218e-02,  1.62080210e-02]],
#
#          ...,
#
#          [[-2.77890731e-03, -5.26150689e-03,  1.20572513e-02, ...,
#           [-3.30882962e-03, -5.55735733e-03, -1.53233996e-02, ...,
#             9.01309680e-03, -1.92048177e-02, -1.35179497e-02]],
#
#          [[ 1.57404616e-02, -1.85298584e-02, -1.48194218e-02, ...,
#             2.33374033e-02,  5.97014241e-02,  8.42978433e-02],
#           [-1.00956000e-02, -5.14338119e-03, -8.03953037e-03, ...,
#             1.04088511e-03,  5.70840053e-02,  8.45262632e-02],
#           [-1.53033948e-03, -1.30410055e-02,  5.90809155e-03, ...,
#             1.20626185e-02,  4.82764989e-02,  8.89347270e-02]],
#
#          ...,
#
#          [[ 5.90945175e-03, -8.50745104e-03, -5.29478043e-02, ...,
#             8.07309058e-03, -1.96499052e-03,  4.64984635e-03],
#           [-1.48619357e-02,  7.20839656e-04, -1.03869243e-02, ...,
#             5.68590732e-03,  4.80930042e-03, -5.18744951e-03],
#           [-4.02818061e-02,  1.27444882e-02,  5.95136210e-02, ...,
#             1.25385663e-02,  3.61638865e-03, -1.54755369e-03]],
#
#          [[-4.82368702e-03, -1.80806052e-02, -4.70731184e-02, ...,
#             7.44890794e-03,  2.74119177e-03, -6.65921625e-03],
#           [-2.96461186e-03, -3.79451155e-03, -1.83262620e-02, ...,
#             1.01405885e-02,  1.39314104e-02, -1.34154351e-03],
#           [-4.72858101e-02, -4.77760052e-03,  4.10567895e-02, ...,
#             1.30711282e-02,  3.62393772e-03, -1.92349385e-02]],
#
#          [[-1.66329462e-02, -3.90663976e-03, -2.16902457e-02, ...,
#             8.82021524e-03, -9.84708895e-04,  5.14718425e-03],
#           [-1.03513822e-02, -5.92208747e-03, -8.18535592e-03, ...,
#            -1.61653326e-03, -7.47126760e-03,  7.56714027e-04],
#           [-4.38118912e-02,  8.39092012e-04,  3.74807119e-02, ...,
#             1.83206350e-02, -7.83686154e-03, -7.65552372e-03]]]],
#        dtype=float32), array([[1]], dtype=uint8), array([[1]], dtype=uint8)),
#          (array(['conv1b'], dtype='<U6'), array([[-0.63998175],
#         [-0.6184286 ],
#         [ 0.04367002],
#         [-0.45373768],
#         [-0.56854177],
#         [-0.7385825 ],
#         [-0.9388133 ],
#         [-0.87714326],
#         [-0.7043287 ],
#         [-0.84178984],
#         [-0.26375467],
#         [-0.28477398],
#         [ 0.15485989],
#         [-0.2621361 ],
#         [-0.2866176 ],
#         [-0.7179949 ],
#         [-0.7165494 ],
#         [-0.7601529 ],
#         [-0.26063594],
#         [-0.6586762 ],
#         [ 0.14669429],
#         [-0.7333699 ],
#         [-0.74048597],
#         [-1.1210668 ],
#         [-0.71023685],
#         [-0.6066158 ],
#         [-0.74022126],
#         [-0.26677907],
#         [-0.46289384],
#         [-0.60795355],
#         [-0.5491112 ],
#         [ 0.03306841],
#         [-0.4659366 ],
#         [-0.50678825],
#         [-0.17822224],
#         [-0.20443553],
#         [-0.5127192 ],
#         [ 0.06807355],
#         [-0.31141132],
#         [-0.24890167],
#         [ 0.10883012],
#         [-0.38636002],
#         [-0.25884962],
#         [-0.75144064],
#         [-0.77844626],
#         [-0.69061434],
#         [-0.4580573 ],
#           ...,
#           [-8.59965291e-03, -5.41064329e-03, -6.74409675e-04, ...,
#             2.03141989e-03, -5.82001684e-03,  1.00926207e-02],
#           [-1.61097199e-02, -1.09475143e-02, -1.88583694e-02, ...,
#            -9.87371430e-03, -4.47302079e-03, -1.67984311e-02],
#           [-5.49391145e-03, -8.51439591e-03,  5.48427040e-03, ...,
#            -3.36732320e-03,  3.17312730e-03, -2.16467101e-02]]]],
#        dtype=float32), array([[1]], dtype=uint8), array([[1]], dtype=uint8)),
#          (array(['conv2b'], dtype='<U6'), array([[0.96902454],
#         [1.0093402 ],
#         [0.99639624],
#         [0.9868492 ],
#         [1.0069045 ],
#         [0.98999524],
#         [1.0073581 ],
#         [0.9817709 ],
#         [1.0079571 ],
#         [0.97236097],
#         [1.0102923 ],
#         [0.96954393],
#         [1.0098863 ],
#         [1.0052117 ],
#         [0.97773486],
#         [1.0109124 ],
#         [0.9855414 ],
#         [1.0187546 ],
#         [1.0070171 ],
#         [0.98347104],
#         [1.0001817 ],
#         [0.9979628 ],
#         [0.99276894],
#         [0.9800123 ],
#         [0.9915675 ],
#         [0.9619934 ],
#         [1.0163885 ],
#         [0.99860704],
#         [0.9847694 ],
#         [0.9994919 ],
#         [0.9994835 ],
#         [0.9732691 ],
#         [0.9977391 ],
#         [1.0022386 ],
#         [1.0133618 ],
#         [0.9891664 ],
#         [0.9929108 ],
#         [0.98750085],
#         [1.0160785 ],
#         [0.97086823],
#         [0.9917297 ],
#         [0.9998288 ],
#         [0.94049627],
#         [1.000726  ],
#         [0.9543493 ],
#         [0.9946856 ],
#         [1.0155579 ],
#         [1.026908  ],
#         [1.0085306 ],
#         [1.0014884 ],
#         [0.9626141 ],
#         [0.9679101 ],
#         [0.9887988 ],
#         [0.97960645],
#         [0.99290276],
#         [0.9903424 ],
#         [1.0100635 ],
#         [0.9990928 ],
#         [1.0227779 ],
#         [0.99767727],
#         [0.9708659 ],
#         [0.98218316],
#         [0.9913387 ],
#         [0.9929041 ],
#         [0.9795552 ],
#         [1.0244076 ],
#         [0.98483956],
#         [0.9937357 ],
#         [0.9776735 ],
#         [1.0056884 ],
#         [0.9949364 ],
#         [0.98501325],
#         [0.98879945],
#         [0.9859043 ],
#         [1.0322914 ],
#         [1.0054253 ],
#         [0.9924964 ],
#         [1.0128945 ],
#         [1.0147201 ],
#         [1.0072336 ],
#         [0.9915018 ],
#         [0.99778813],
#         [1.0238949 ],
#         [0.9991736 ],
#         [1.0094802 ],
#         [0.99793535],
#         [1.0087112 ],
#         [1.0038395 ],
#         [0.99619937],
#         [0.97204894],
#         [1.0035386 ],
#         [1.0350143 ],
#         [1.0054554 ],
#         [1.0172423 ],
#         [1.0342665 ],
#         [0.99092185],
#         [0.98879105],
#         [0.9740447 ],
#         [1.014757  ],
#         [0.953448  ],
#         [1.0291872 ],
#         [0.9738086 ],
#         [1.0175937 ],
#         [0.9865909 ],
#         [1.0084562 ],
#         [1.0136313 ],
#         [0.981537  ],
#         [1.0106846 ],
#         [0.98572356],
#         [1.0046366 ],
#         [0.957034  ],
#         [0.985631  ],
#         [0.9845975 ],
#         [0.9968711 ],
#         [1.0128084 ],
#         [1.002917  ],
#         [0.9934983 ],
#         [1.0041826 ],
#         [0.98698044],
#         [1.00188   ],
#         [0.996634  ],
#         [0.9782988 ],
#         [0.99778116],
#         [1.0102051 ],
#         [1.001622  ],
#         [0.9867753 ],
#         [1.0027199 ],
#         [0.9918864 ],
#         [0.9862703 ],
#         [1.0274056 ],
#         [1.0030956 ],
#         [0.9905242 ],
#         [1.0060021 ],
#         [1.0021875 ],
#         [0.9769408 ],
#         [1.0121249 ],
#         [0.9706365 ],
#         [0.9706716 ],
#         [1.0169764 ],
#         [1.0061728 ],
#         [1.0018914 ],
#         [0.98007965],
#         [0.9837583 ],
#         [0.9730772 ],
#         [0.99617195],
#         [0.9712773 ],
#         [0.974376  ],
#         [1.0131949 ],
#         [0.9729188 ],
#         [1.002741  ],
#         [0.98047906],
#         [1.0180446 ],
#         [0.98687595],
#         [0.99689054],
#         [1.0118061 ],
#         [0.9982956 ],
#         [0.98068786],
#         [0.98916245],
#         [0.9939197 ],
#         [1.0139021 ],
#         [0.9849354 ],
#         [1.0017089 ],
#         [1.0008417 ],
#         [1.0080404 ],
#         [0.9693671 ],
#         [0.9933865 ],
#         [0.98866254],
#         [1.008331  ],
#         [0.9731471 ],
#         [0.9986387 ],
#         [1.033487  ],
#         [1.0092952 ],
#         [1.0123085 ],
#         [0.9659144 ],
#         [0.97369486],
#         [1.0046836 ],
#         [0.964862  ],
#         [0.960533  ],
#         [0.9627212 ],
#         [0.99610686],
#         [0.9657213 ],
#         [1.003007  ],
#         [1.0095608 ],
#         [0.97801346],
#         [0.98060125],
#         [0.98027194],
#         [1.0097007 ],
#         [0.9818198 ],
#         [0.9958438 ],
#         [1.014725  ],
#         [1.0095297 ],
#         [0.9901208 ],
#         [0.9854345 ],
#         [0.97461486],
#         [1.0083046 ],
#         [0.9915386 ],
#         [1.0147724 ],
#         [1.0079224 ],
#         [0.9935016 ],
#         [1.025932  ],
#         [0.9979583 ],
#         [0.99030757],
#         [0.96257067],
#         [0.99200577],
#         [0.99502546],
#         [1.0187014 ],
#         [0.9982488 ],
#         [0.98843336],
#         [1.0149622 ],
#         [1.0152273 ],
#         [0.9706137 ],
#         [1.0126206 ],
#         [1.0204643 ],
#         [0.98909146],
#         [0.98339206],
#         [0.96881187],
#         [1.0037097 ],
#         [0.9656558 ],
#         [0.9901411 ],
#         [1.0126309 ],
#         [1.0035559 ],
#         [1.0082724 ],
#         [0.99077344],
#         [0.98638105],
#         [0.9986094 ],
#         [0.985593  ],
#         [0.9846563 ],
#         [1.0166128 ],
#         [0.9690609 ],
#         [0.9876309 ],
#         [0.99415135],
#         [1.0042855 ],
#         [0.9817618 ],
#         [1.0176644 ],
#         [1.0201273 ],
#         [0.9917058 ],
#         [1.0125874 ],
#         [0.99646676],
#         [1.0166416 ],
#         [0.99073863],
#         [0.99950486],
#         [1.0015235 ],
#         [0.9929471 ],
#         [0.9683966 ],
#         [1.0180684 ],
#         [0.9829866 ],
#         [0.9933006 ],
#         [1.0010246 ],
#         [0.9996184 ],
#         [0.99521655],
#         [0.97574717],
#         [1.0049677 ],
#         [1.0017958 ],
#         [0.99373084],
#         [1.0010518 ],
#         [0.9786457 ]], dtype=float32), array([[1]], dtype=uint8), array([[0]], dtype=uint8)),
#           [-1.75142009e-02,  3.33605846e-03,  9.66600329e-03, ...,
#            -6.43021800e-03, -5.74155292e-03, -2.48265779e-03],
#           [-6.94713183e-03, -3.68027319e-03,  1.81669071e-02, ...,
#            -1.27094025e-02, -7.13796541e-03,  3.19075733e-02],
#           ...,
#           [ 1.59897536e-04, -2.28977334e-02, -2.25123912e-02, ...,
#            -2.77828076e-03, -5.53406309e-03, -2.10308321e-02],
#           [ 1.15869064e-02, -2.34232247e-02, -6.45118812e-03, ...,
#             2.63076313e-02,  1.87244862e-02,  1.58476308e-02],
#           [-6.90981792e-03, -2.32453495e-02,  1.58627648e-02, ...,
#            -5.64667163e-04,  3.48534877e-03, -2.71380171e-02]],
#
#          [[ 2.08243839e-02,  6.80185575e-03,  2.21417379e-02, ...,
#             7.43992403e-02, -4.61282022e-03, -1.69627704e-02],
#           [-1.49110463e-02, -2.90985522e-03,  2.66326182e-02, ...,
#             7.82417250e-04, -5.81869949e-03, -3.64019373e-03],
#           [-6.68954384e-03,  4.72678058e-03, -7.90893566e-03, ...,
#            -1.65968444e-02,  2.82717985e-03,  2.77811028e-02],
#           ...,
#           [-1.18760264e-03, -1.95885263e-02, -3.27083259e-03, ...,
#            -2.00546570e-02, -7.32770655e-03, -2.97205877e-02],
#           [-3.62024158e-02, -2.30062921e-02, -3.13076787e-02, ...,
#             5.46712615e-02,  9.80543438e-03,  3.31377331e-03],
#           [ 1.35794710e-02, -2.68666949e-02,  2.58336659e-03, ...,
# ...
#           [ 0.00363054, -0.00263319, -0.0087486 , ..., -0.00477915,
#             0.01197852, -0.01009519]]]], dtype=float32), array([[1]], dtype=uint8), array([[1]], dtype=uint8)),
#          (array(['fc7b'], dtype='<U4'), array([[1.100905  ],
#         [0.92883605],
#         [1.0641418 ],
#         ...,
#         [1.01993   ],
#         [1.0505271 ],
#         [0.96275264]], dtype=float32), array([[1]], dtype=uint8), array([[0]], dtype=uint8)),
#          (array(['fc8Cf'], dtype='<U5'), array([[[[-0.00164798, -0.00845108,  0.01451046, ...,  0.00221218,
#            -0.00427154,  0.02097076],
#           [-0.02567742,  0.00045425, -0.00760302, ...,  0.00720346,
#             0.0056415 ,  0.01971571],
#           [ 0.01940915, -0.02000385, -0.01229079, ...,  0.00436201,
#            -0.0058065 ,  0.01699321],
#           ...,
#           [-0.00251668,  0.00311217, -0.00545637, ...,  0.00491279,
#             0.0189395 ,  0.00165126],
#           [ 0.01778923,  0.00371478,  0.00804058, ...,  0.01739382,
#             0.00620617,  0.01430643],
#           [ 0.00985409, -0.00424933,  0.04876088, ...,  0.01905548,
#            -0.01010114, -0.00377146]]]], dtype=float32), array([[1]], dtype=uint8), array([[1]], dtype=uint8)),
#          (array(['fc8Cb'], dtype='<U5'), array([[ 0.00322932, -0.00365643,  0.01788319,  0.00304264,  0.00317066,
#          -0.00579671,  0.00262951,  0.00237554,  0.00144072, -0.00493429,
#          -0.00112192, -0.00164633, -0.00505965, -0.00548832,  0.006413  ,
#          -0.00569885, -0.0050097 ,  0.00226981, -0.00037987, -0.00366249]],
#        dtype=float32), array([[1]], dtype=uint8), array([[0]], dtype=uint8)),
#          (array(['fc8Rf'], dtype='<U5'), array([[[[-0.0175763 ,  0.00571099, -0.00467239, ..., -0.02129661,
#             0.00893233, -0.00496777],
#           [ 0.01731838, -0.01010705,  0.01066526, ...,  0.01333513,
#            -0.02142037,  0.0100906 ],
#           [ 0.00967855, -0.00808099,  0.0032165 , ..., -0.00254026,
#            -0.00570787,  0.01821664],
#           ...,
#           [ 0.00556248,  0.00547204, -0.00707551, ...,  0.01119848,
#             0.03899863,  0.01800256],
#           [ 0.00248244, -0.0051239 ,  0.00219742, ..., -0.00976763,
#            -0.00623978, -0.00517104],
#           [ 0.01139982, -0.01319748,  0.02948631, ...,  0.00897494,
#             0.00380487, -0.00454674]]]], dtype=float32), array([[1]], dtype=uint8), array([[1]], dtype=uint8)),
#          (array(['fc8Rb'], dtype='<U5'), array([[ 1.08802925e-10,  1.02774989e-09,  6.90982715e-10,
#           3.32348454e-10, -1.85441085e-09,  1.27083266e-09,
#          -5.77735371e-09, -6.77989647e-08, -1.62912972e-08,
#           1.19310362e-09,  8.13931866e-10,  5.70448355e-09,
#           3.22277938e-09,  3.60567354e-10, -4.31530545e-08,
#          -3.30694383e-09,  6.35748065e-10, -1.07542686e-09,
#          -4.51787896e-09, -1.08615179e-08]], dtype=float32), array([[1]], dtype=uint8), array([[0]], dtype=uint8))]],
#        dtype=[('name', 'O'), ('value', 'O'), ('learningRate', 'O'), ('weightDecay', 'O')]),
#  'layers': array([[(array(['conv1'], dtype='<U5'), array(['dagnn.Conv'], dtype='<U10'), array([[array(['input'], dtype='<U5')]], dtype=object), array([[array(['x1'], dtype='<U2')]], dtype=object), array([[array(['conv1f'], dtype='<U6'), array(['conv1b'], dtype='<U6')]],
#        dtype=object), array([[(array([[11, 11,  3, 64]], dtype=uint8), array([[1]], dtype=uint8), array([], shape=(0, 0), dtype=object), array([[0, 0, 0, 0]], dtype=uint8), array([[4, 4]], dtype=uint8), array([[1, 1]], dtype=uint8))]],
#        dtype=[('size', 'O'), ('hasBias', 'O'), ('opts', 'O'), ('pad', 'O'), ('stride', 'O'), ('dilate', 'O')])),
#          (array(['relu1'], dtype='<U5'), array(['dagnn.ReLU'], dtype='<U10'), array([[array(['x1'], dtype='<U2')]], dtype=object), array([[array(['x2'], dtype='<U2')]], dtype=object), array([], shape=(0, 0), dtype=object), array([[(array([[1]], dtype=uint8), array([[0]], dtype=uint8), array([], shape=(0, 0), dtype=object))]],
#        dtype=[('useShortCircuit', 'O'), ('leak', 'O'), ('opts', 'O')])),
#          (array(['norm1'], dtype='<U5'), array(['dagnn.LRN'], dtype='<U9'), array([[array(['x2'], dtype='<U2')]], dtype=object), array([[array(['x3'], dtype='<U2')]], dtype=object), array([], shape=(0, 0), dtype=object), array([[(array([[5.0e+00, 2.0e+00, 1.0e-04, 7.5e-01]]),)]],
#        dtype=[('param', 'O')])),
#          (array(['pool1'], dtype='<U5'), array(['dagnn.Pooling'], dtype='<U13'), array([[array(['x3'], dtype='<U2')]], dtype=object), array([[array(['x4'], dtype='<U2')]], dtype=object), array([], shape=(0, 0), dtype=object), array([[(array(['max'], dtype='<U3'), array([[3, 3]], dtype=uint8), array([], shape=(0, 0), dtype=object), array([[0, 1, 0, 1]], dtype=uint8), array([[2, 2]], dtype=uint8), array([[1, 1]], dtype=uint8))]],
#        dtype=[('method', 'O'), ('poolSize', 'O'), ('opts', 'O'), ('pad', 'O'), ('stride', 'O'), ('dilate', 'O')])),
#          (array(['conv2'], dtype='<U5'), array(['dagnn.Conv'], dtype='<U10'), array([[array(['x4'], dtype='<U2')]], dtype=object), array([[array(['x5'], dtype='<U2')]], dtype=object), array([[array(['conv2f'], dtype='<U6'), array(['conv2b'], dtype='<U6')]],
#        dtype=object), array([[(array([[  5,   5,  64, 256]], dtype=uint16), array([[1]], dtype=uint8), array([], shape=(0, 0), dtype=object), array([[2, 2, 2, 2]], dtype=uint8), array([[1, 1]], dtype=uint8), array([[1, 1]], dtype=uint8))]],
#        dtype=[('size', 'O'), ('hasBias', 'O'), ('opts', 'O'), ('pad', 'O'), ('stride', 'O'), ('dilate', 'O')])),
#          (array(['relu2'], dtype='<U5'), array(['dagnn.ReLU'], dtype='<U10'), array([[array(['x5'], dtype='<U2')]], dtype=object), array([[array(['x6'], dtype='<U2')]], dtype=object), array([], shape=(0, 0), dtype=object), array([[(array([[1]], dtype=uint8), array([[0]], dtype=uint8), array([], shape=(0, 0), dtype=object))]],
#        dtype=[('useShortCircuit', 'O'), ('leak', 'O'), ('opts', 'O')])),
#          (array(['norm2'], dtype='<U5'), array(['dagnn.LRN'], dtype='<U9'), array([[array(['x6'], dtype='<U2')]], dtype=object), array([[array(['x7'], dtype='<U2')]], dtype=object), array([], shape=(0, 0), dtype=object), array([[(array([[5.0e+00, 2.0e+00, 1.0e-04, 7.5e-01]]),)]],
#        dtype=[('param', 'O')])),
#          (array(['pool2'], dtype='<U5'), array(['dagnn.Pooling'], dtype='<U13'), array([[array(['x7'], dtype='<U2')]], dtype=object), array([[array(['x8'], dtype='<U2')]], dtype=object), array([], shape=(0, 0), dtype=object), array([[(array(['max'], dtype='<U3'), array([[3, 3]], dtype=uint8), array([], shape=(0, 0), dtype=object), array([[0, 1, 0, 1]], dtype=uint8), array([[2, 2]], dtype=uint8), array([[1, 1]], dtype=uint8))]],
#        dtype=[('method', 'O'), ('poolSize', 'O'), ('opts', 'O'), ('pad', 'O'), ('stride', 'O'), ('dilate', 'O')])),
#          (array(['conv3'], dtype='<U5'), array(['dagnn.Conv'], dtype='<U10'), array([[array(['x8'], dtype='<U2')]], dtype=object), array([[array(['x9'], dtype='<U2')]], dtype=object), array([[array(['conv3f'], dtype='<U6'), array(['conv3b'], dtype='<U6')]],
#        dtype=object), array([[(array([[  3,   3, 256, 256]], dtype=uint16), array([[1]], dtype=uint8), array([], shape=(0, 0), dtype=object), array([[1, 1, 1, 1]], dtype=uint8), array([[1, 1]], dtype=uint8), array([[1, 1]], dtype=uint8))]],
#        dtype=[('size', 'O'), ('hasBias', 'O'), ('opts', 'O'), ('pad', 'O'), ('stride', 'O'), ('dilate', 'O')])),
#          (array(['relu3'], dtype='<U5'), array(['dagnn.ReLU'], dtype='<U10'), array([[array(['x9'], dtype='<U2')]], dtype=object), array([[array(['x10'], dtype='<U3')]], dtype=object), array([], shape=(0, 0), dtype=object), array([[(array([[1]], dtype=uint8), array([[0]], dtype=uint8), array([], shape=(0, 0), dtype=object))]],
#        dtype=[('useShortCircuit', 'O'), ('leak', 'O'), ('opts', 'O')])),
#          (array(['conv4'], dtype='<U5'), array(['dagnn.Conv'], dtype='<U10'), array([[array(['x10'], dtype='<U3')]], dtype=object), array([[array(['x11'], dtype='<U3')]], dtype=object), array([[array(['conv4f'], dtype='<U6'), array(['conv4b'], dtype='<U6')]],
#        dtype=object), array([[(array([[  3,   3, 256, 256]], dtype=uint16), array([[1]], dtype=uint8), array([], shape=(0, 0), dtype=object), array([[1, 1, 1, 1]], dtype=uint8), array([[1, 1]], dtype=uint8), array([[1, 1]], dtype=uint8))]],
#        dtype=[('size', 'O'), ('hasBias', 'O'), ('opts', 'O'), ('pad', 'O'), ('stride', 'O'), ('dilate', 'O')])),
#          (array(['relu4'], dtype='<U5'), array(['dagnn.ReLU'], dtype='<U10'), array([[array(['x11'], dtype='<U3')]], dtype=object), array([[array(['x12'], dtype='<U3')]], dtype=object), array([], shape=(0, 0), dtype=object), array([[(array([[1]], dtype=uint8), array([[0]], dtype=uint8), array([], shape=(0, 0), dtype=object))]],
#        dtype=[('useShortCircuit', 'O'), ('leak', 'O'), ('opts', 'O')])),
#          (array(['conv5'], dtype='<U5'), array(['dagnn.Conv'], dtype='<U10'), array([[array(['x12'], dtype='<U3')]], dtype=object), array([[array(['x13'], dtype='<U3')]], dtype=object), array([[array(['conv5f'], dtype='<U6'), array(['conv5b'], dtype='<U6')]],
#        dtype=object), array([[(array([[  3,   3, 256, 256]], dtype=uint16), array([[1]], dtype=uint8), array([], shape=(0, 0), dtype=object), array([[1, 1, 1, 1]], dtype=uint8), array([[1, 1]], dtype=uint8), array([[1, 1]], dtype=uint8))]],
#        dtype=[('size', 'O'), ('hasBias', 'O'), ('opts', 'O'), ('pad', 'O'), ('stride', 'O'), ('dilate', 'O')])),
#          (array(['relu5'], dtype='<U5'), array(['dagnn.ReLU'], dtype='<U10'), array([[array(['x13'], dtype='<U3')]], dtype=object), array([[array(['x14'], dtype='<U3')]], dtype=object), array([], shape=(0, 0), dtype=object), array([[(array([[1]], dtype=uint8), array([[0]], dtype=uint8), array([], shape=(0, 0), dtype=object))]],
#        dtype=[('useShortCircuit', 'O'), ('leak', 'O'), ('opts', 'O')])),
#          (array(['fc6'], dtype='<U3'), array(['dagnn.Conv'], dtype='<U10'), array([[array(['xBoostBox'], dtype='<U9')]], dtype=object), array([[array(['x15'], dtype='<U3')]], dtype=object), array([[array(['fc6f'], dtype='<U4'), array(['fc6b'], dtype='<U4')]],
#        dtype=object), array([[(array([[   6,    6,  256, 4096]], dtype=uint16), array([[1]], dtype=uint8), array([], shape=(0, 0), dtype=object), array([[0, 0, 0, 0]], dtype=uint8), array([[1, 1]], dtype=uint8), array([[1, 1]], dtype=uint8))]],
#        dtype=[('size', 'O'), ('hasBias', 'O'), ('opts', 'O'), ('pad', 'O'), ('stride', 'O'), ('dilate', 'O')])),
#          (array(['relu6'], dtype='<U5'), array(['dagnn.ReLU'], dtype='<U10'), array([[array(['x15'], dtype='<U3')]], dtype=object), array([[array(['x16'], dtype='<U3')]], dtype=object), array([], shape=(0, 0), dtype=object), array([[(array([[1]], dtype=uint8), array([[0]], dtype=uint8), array([], shape=(0, 0), dtype=object))]],
#        dtype=[('useShortCircuit', 'O'), ('leak', 'O'), ('opts', 'O')])),
#          (array(['fc7'], dtype='<U3'), array(['dagnn.Conv'], dtype='<U10'), array([[array(['x16'], dtype='<U3')]], dtype=object), array([[array(['x18'], dtype='<U3')]], dtype=object), array([[array(['fc7f'], dtype='<U4'), array(['fc7b'], dtype='<U4')]],
#        dtype=object), array([[(array([[   1,    1, 4096, 4096]], dtype=uint16), array([[1]], dtype=uint8), array([], shape=(0, 0), dtype=object), array([[0, 0, 0, 0]], dtype=uint8), array([[1, 1]], dtype=uint8), array([[1, 1]], dtype=uint8))]],
#        dtype=[('size', 'O'), ('hasBias', 'O'), ('opts', 'O'), ('pad', 'O'), ('stride', 'O'), ('dilate', 'O')])),
#          (array(['relu7'], dtype='<U5'), array(['dagnn.ReLU'], dtype='<U10'), array([[array(['x18'], dtype='<U3')]], dtype=object), array([[array(['x19'], dtype='<U3')]], dtype=object), array([], shape=(0, 0), dtype=object), array([[(array([[1]], dtype=uint8), array([[0]], dtype=uint8), array([], shape=(0, 0), dtype=object))]],
#        dtype=[('useShortCircuit', 'O'), ('leak', 'O'), ('opts', 'O')])),
#          (array(['fc8C'], dtype='<U4'), array(['dagnn.Conv'], dtype='<U10'), array([[array(['x19'], dtype='<U3')]], dtype=object), array([[array(['xfc8C'], dtype='<U5')]], dtype=object), array([[array(['fc8Cf'], dtype='<U5'), array(['fc8Cb'], dtype='<U5')]],
#        dtype=object), array([[(array([[   1,    1, 4096,   20]], dtype=uint16), array([[1]], dtype=uint8), array([], shape=(0, 0), dtype=object), array([[0, 0, 0, 0]], dtype=uint8), array([[1, 1]], dtype=uint8), array([[1, 1]], dtype=uint8))]],
#        dtype=[('size', 'O'), ('hasBias', 'O'), ('opts', 'O'), ('pad', 'O'), ('stride', 'O'), ('dilate', 'O')])),
#          (array(['fc8R'], dtype='<U4'), array(['dagnn.Conv'], dtype='<U10'), array([[array(['x19'], dtype='<U3')]], dtype=object), array([[array(['x22'], dtype='<U3')]], dtype=object), array([[array(['fc8Rf'], dtype='<U5'), array(['fc8Rb'], dtype='<U5')]],
#        dtype=object), array([[(array([[   1,    1, 4096,   20]], dtype=uint16), array([[1]], dtype=uint8), array([], shape=(0, 0), dtype=object), array([[0, 0, 0, 0]], dtype=uint8), array([[1, 1]], dtype=uint8), array([[1, 1]], dtype=uint8))]],
#        dtype=[('size', 'O'), ('hasBias', 'O'), ('opts', 'O'), ('pad', 'O'), ('stride', 'O'), ('dilate', 'O')])),
#          (array(['SPP'], dtype='<U3'), array(['dagnn.ROIPooling'], dtype='<U16'), array([[array(['x14'], dtype='<U3'), array(['rois'], dtype='<U4')]],
#        dtype=object), array([[array(['xSPP'], dtype='<U4')]], dtype=object), array([], shape=(0, 0), dtype=object), array([[(array(['max'], dtype='<U3'), array([[6, 6]], dtype=uint8), array([[1]], dtype=uint8), array([[0]], dtype=uint8))]],
#        dtype=[('method', 'O'), ('subdivisions', 'O'), ('transform', 'O'), ('flatten', 'O')])),
#          (array(['boostBox'], dtype='<U8'), array(['dagnn.BiasSamples'], dtype='<U17'), array([[array(['xSPP'], dtype='<U4'), array(['boxScore'], dtype='<U8')]],
#        dtype=object), array([[array(['xBoostBox'], dtype='<U9')]], dtype=object), array([], shape=(0, 0), dtype=object), array([[(array([[10]], dtype=uint8),)]], dtype=[('scale', 'O')])),
#          (array(['softmaxDet'], dtype='<U10'), array(['dagnn.SoftMax2'], dtype='<U14'), array([[array(['x22'], dtype='<U3')]], dtype=object), array([[array(['xSoftmaxDet'], dtype='<U11')]], dtype=object), array([], shape=(0, 0), dtype=object), array([[(array([[4.]], dtype=float32), array([[2.]], dtype=float32), array([[1.]], dtype=float32))]],
#        dtype=[('dim', 'O'), ('temp', 'O'), ('scale', 'O')])),
#          (array(['softmaxCls'], dtype='<U10'), array(['dagnn.SoftMax2'], dtype='<U14'), array([[array(['xfc8C'], dtype='<U5')]], dtype=object), array([[array(['xSoftmaxCls'], dtype='<U11')]], dtype=object), array([], shape=(0, 0), dtype=object), array([[(array([[3.]], dtype=float32), array([[1.]], dtype=float32), array([[1.]], dtype=float32))]],
#        dtype=[('dim', 'O'), ('temp', 'O'), ('scale', 'O')])),
#          (array(['timesCR'], dtype='<U7'), array(['dagnn.Times'], dtype='<U11'), array([[array(['xSoftmaxCls'], dtype='<U11'),
#          array(['xSoftmaxDet'], dtype='<U11')]], dtype=object), array([[array(['xTimes'], dtype='<U6')]], dtype=object), array([], shape=(0, 0), dtype=object), array([[None]], dtype=object)),
#          (array(['sum'], dtype='<U3'), array(['dagnn.SumOverDim'], dtype='<U16'), array([[array(['xTimes'], dtype='<U6')]], dtype=object), array([[array(['prediction'], dtype='<U10')]], dtype=object), array([], shape=(0, 0), dtype=object), array([[(array([[4]], dtype=uint8),)]], dtype=[('dim', 'O')]))]],
#        dtype=[('name', 'O'), ('type', 'O'), ('inputs', 'O'), ('outputs', 'O'), ('params', 'O'), ('block', 'O')]),
#  'meta': array([[(array([[(array(['bilinear'], dtype='<U8'), array([[[115.59001 , 108.568214, 100.046394]]], dtype=float32), array([[-0.48737794, -2.359288  ,  6.468998  ],
#         [ 1.079989  ,  0.1386027 ,  6.6894255 ],
#         [-0.60755163,  2.1390023 ,  6.701748  ]], dtype=float32))]],
#        dtype=[('interpolation', 'O'), ('averageImage', 'O'), ('rgbVariance', 'O')]), array([[(array([[0]], dtype=uint8),)]], dtype=[('jitterBrightness', 'O')]))]],
#        dtype=[('normalization', 'O'), ('augmentation', 'O')])}

# %%
def show_layer_info(layer_info):
    if layer_info['type'][0][0] == 'conv':
        print('[conv]:')
        for i in ['size', 'pad', 'stride', 'dilate']:
            print(i + ": ")
            print(layer_info[i][0][0])
    elif layer_info['type'][0][0] == 'pool':
        print('[pool]:')
        for i in ['method', 'pool', 'stride', 'pad']:
            print(i + ": ")
            print(layer_info[i][0][0])
    else:
        print(layer_info['type'][0][0])
