# %%
import torch
import torch.utils.data as data
import torchvision
import torchvision.datasets as datasets
import numpy as np
import selective_search

# %%
voc_07_trainval = datasets.VOCDetection("~/data/", '2007', 'trainval', download=False)

# %%
anno['annotation']['filename']
# Out:
# '000030.jpg'

# %%
voc_07_trainval_boxex = []
for img, anno in voc_07_trainval:
    img = np.array(img)
    boxes = selective_search.selective_search(img, mode='fast')
    boxes_filter = selective_search.box_filter(boxes, min_size=20, topN=40)
    voc_07_trainval_boxex.append(boxes_filter)
np.save('../region/07_trainval_ssw.npy', voc_07_trainval)
# Out:
# Exception in thread Thread-8:
# Traceback (most recent call last):
#   File "/home/shenjiajie/.conda/envs/sjjenv/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/home/shenjiajie/.conda/envs/sjjenv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 558, in run
#     self.terminate_broken(bpe)
#   File "/home/shenjiajie/.conda/envs/sjjenv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 736, in terminate_broken
#     self.kill_workers()
#   File "/home/shenjiajie/.conda/envs/sjjenv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 766, in kill_workers
#     recursive_terminate(p)
#   File "/home/shenjiajie/.conda/envs/sjjenv/lib/python3.8/site-packages/joblib/externals/loky/backend/utils.py", line 28, in recursive_terminate
#     _recursive_terminate_without_psutil(process)
# ...

# %%
boxes_filter
# Out:
# [(0, 0, 500, 333),
#  (51, 0, 91, 62),
#  (287, 81, 346, 115),
#  (294, 183, 341, 217),
#  (0, 189, 89, 239),
#  (0, 191, 89, 239),
#  (198, 120, 500, 189),
#  (198, 120, 396, 156),
#  (404, 16, 428, 49),
#  (253, 120, 396, 155),
#  (0, 191, 89, 235),
#  (103, 202, 295, 247),
#  (103, 202, 192, 233),
#  (103, 204, 192, 233),
#  (286, 152, 500, 189),
#  (0, 125, 191, 196),
#  (0, 125, 191, 187),
#  (0, 125, 142, 187),
#  (0, 125, 93, 187),
#  (31, 125, 92, 149),
#  (0, 98, 160, 122),
#  (317, 154, 500, 189),
#  (331, 154, 500, 180),
#  (331, 156, 500, 180),
#  (467, 156, 500, 180),
#  (345, 205, 500, 232),
#  (384, 208, 500, 232),
#  (0, 148, 93, 187),
#  (95, 125, 187, 151),
#  (317, 160, 500, 189),
#  (187, 218, 295, 247),
#  (405, 120, 488, 155),
#  (405, 120, 486, 155),
#  (0, 148, 500, 333),
#  (189, 148, 331, 185),
#  (189, 150, 331, 185),
#  (189, 150, 331, 181),
#  (0, 0, 500, 174),
#  (0, 79, 270, 109),
#  (0, 98, 104, 122)]

# %%
voc_07_trainval[2][0]
# Out:
# <PIL.Image.Image image mode=RGB size=500x375 at 0x7F3859674C40>
